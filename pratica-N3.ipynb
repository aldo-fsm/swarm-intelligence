# %%
import numpy as np
from matplotlib import pyplot as plt
from aco.ant_system import AntSystem, Point
from tqdm import tqdm_notebook

# %%
num_iterations = 2500
antSystem = AntSystem(
    alpha=1,
    beta=5,
    evaporation_rate=0.5,
    Q=100,
    initial_pheromone=1
)

# %%
num_points = 30
points = []
for point in 10*np.random.randn(num_points, 2):
    points.append(Point(point))

# %%
antSystem.initialize(points)
path_length_history = []
for i in tqdm_notebook(range(num_iterations)):
    antSystem.step()
    path_length_history.append(antSystem.bestSolution[1])

# %%
plt.grid()
plt.plot(path_length_history)
plt.xlabel('iteration')
plt.ylabel('path length')
# Out:
# Text(0, 0.5, 'path length')

# %%
plt.grid()
positions = np.array([p.position for p in points])
path = positions[antSystem.bestSolution[0]].T
plt.scatter(*positions.T)
plt.plot(*np.concatenate([path, path[:,[0]]], axis=1))
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')
